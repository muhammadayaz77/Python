# %%
import pandas as pd

# %%
dataset = pd.read_csv("Data-Files/HousePricesData.csv")
dataset
# Out:
#     House Size (sq meters)  Price (USD)
# 0                      143       739916
# 1                      287      1452412
# 2                      232      1186827
# 3                      199       978571
# 4                       89       460629
# ..                     ...          ...
# 95                     173       870928
# 96                     180       921874
# 97                     156       811249
# 98                      56       307307
# 99                      76       421407
#
# [100 rows x 2 columns]

# %%
x_area = dataset["House Size (sq meters)"].tolist()
print(x_area)
# Out:
# [143, 287, 232, 199, 89, 88, 64, 266, 200, 227, 55, 292, 258, 103, 95, 95, 126, 181, 157, 122, 202, 84, 123, 141, 164, 246, 99, 178, 198, 61, 201, 92, 66, 287, 291, 252, 126, 74, 221, 160, 80, 173, 58, 277, 114, 215, 127, 180, 186, 96, 292, 243, 284, 273, 199, 280, 72, 98, 61, 131, 147, 117, 257, 139, 120, 185, 85, 250, 68, 296, 243, 99, 51, 253, 226, 232, 242, 68, 139, 78, 265, 205, 132, 65, 127, 131, 232, 209, 271, 168, 79, 228, 240, 190, 242, 173, 180, 156, 56, 76]

# %%
y_price = dataset["Price (USD)"].tolist()
print(y_price)
# Out:
# [739916, 1452412, 1186827, 978571, 460629, 472135, 372162, 1342354, 1005223, 1145055, 314038, 1488962, 1299958, 545689, 499222, 518628, 636261, 919392, 802089, 604766, 1040738, 449588, 635283, 723260, 811780, 1243057, 512737, 896747, 1007292, 336144, 1067154, 486646, 356465, 1454618, 1438664, 1279966, 651971, 441354, 1121444, 826221, 421853, 865597, 335842, 1421689, 609295, 1079965, 687694, 892048, 965124, 544877, 1462170, 1227590, 1446366, 1378464, 986361, 1423714, 359369, 524450, 308145, 707661, 740181, 602745, 1322192, 691324, 625717, 974512, 414005, 1276438, 368385, 1519245, 1210566, 491985, 287341, 1295266, 1158581, 1188187, 1220487, 367200, 723943, 400549, 1386194, 1058599, 659796, 362579, 639234, 692220, 1205179, 1050533, 1398283, 868524, 435934, 1199491, 1216073, 956521, 1215918, 870928, 921874, 811249, 307307, 421407]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_area,y_price,marker='x',color='r')
plt.title("House Sizes With Prices")
plt.xlabel("House Size in square meters(Ayaz)")
plt.ylabel("House Price in USD $")
plt.show()
# Out:
# Text(0, 0.5, 'House Price in USD $')

# %%
import random
w = round(random.random(), 2)
b = round(random.random(), 2)
print(w, b)
# Out:
# 0.67 0.35

# %%
def calculate_total_cost(x,y,w,b):
    m = len(y)
    total_cost = 0
    for i in range(m):
        y_predicted = w*x[i] + b
        cost = (y_predicted - y[i])**2
        total_cost += cost
    total_cost /= (2*m)
    return total_cost

# %%
calculate_total_cost(x_area,y_price,w,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 calculate_total_cost(x_area,y_price,w,b)
#
# NameError: name 'x_area' is not defined
